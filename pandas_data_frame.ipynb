# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Amazon Sale Report.csv')
df
# Out:
# /tmp/ipython-input-2478617843.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Amazon Sale Report.csv')
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# ...

# %% [markdown]
# # DataFrame Attributes and Methods

# %% [markdown]
# Attribute	- Data stored on an object or class.	syntax - object_name.attribute_name

# %% [markdown]
# Function	- Standalone block of reusable code.	syntax - function_name()

# %% [markdown]
# Method	-Function defined inside a class, called on an object.	syntax - object_name.method_name()

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=128975, step=1)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, '405-8078784-5731545', '04-30-22', ..., False, 'Easy Ship',
#         nan],
#        [1, '171-9198151-1101146', '04-30-22', ..., False, 'Easy Ship',
#         nan],
#        [2, '404-0687676-7273146', '04-30-22', ..., True, nan, nan],
#        ...,
#        [128972, '407-9547469-3152358', '05-31-22', ..., False, nan,
#         False],
#        [128973, '402-6184140-0545956', '05-31-22', ..., False, nan,
#         False],
#        [128974, '408-7436540-8728312', '05-31-22', ..., False, nan,
#         False]], dtype=object)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.sample()
# Out:
#        index             Order ID      Date   Status Fulfilment  \
# 98328  98328  405-7122030-7867531  06-23-22  Shipped     Amazon
#
#       Sales Channel  ship-service-level   Style             SKU Category  ...  \
# 98328      Amazon.in          Expedited  SET363  SET363-KR-NP-S      Set  ...
#
#       currency  Amount           ship-city  ship-state ship-postal-code  \
# 98328      INR  1115.0  THIRUVANANTHAPURAM      KERALA         695011.0
#
#        ship-country                                 promotion-ids    B2B  \
# 98328            IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#        fulfilled-by Unnamed: 22
# 98328           NaN       False
#
# [1 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.isnull()
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel   \
# 0       False     False  False   False       False           False
# 1       False     False  False   False       False           False
# 2       False     False  False   False       False           False
# 3       False     False  False   False       False           False
# 4       False     False  False   False       False           False
# ...       ...       ...    ...     ...         ...             ...
# 128970  False     False  False   False       False           False
# 128971  False     False  False   False       False           False
# 128972  False     False  False   False       False           False
# 128973  False     False  False   False       False           False
# 128974  False     False  False   False       False           False
#
#         ship-service-level  Style    SKU  Category  ...  currency  Amount  \
# 0                    False  False  False     False  ...     False   False
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 128970    False
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# Length: 128975, dtype: bool

# %%
df.rename(columns={'SKU':'stock keeping unit'},inplace=True)

# %%
df.head(2)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel  ship-service-level    Style stock keeping unit  \
# 0   Merchant      Amazon.in           Standard   SET389     SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781    JNE3781-KR-XXXL
#
#   Category  ... currency  Amount  ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62     MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00  BENGALURU    KARNATAKA         560085.0
#
#    ship-country                                      promotion-ids    B2B  \
# 0            IN                                                NaN  False
# 1            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
# ...

# %%
df['Amount'].sum()
# Out:
# np.float64(78592678.29999998)

# %%
df['Amount'].mean()
# Out:
# np.float64(648.5614647631621)

# %%
df['Qty'].sum()
# Out:
# np.int64(116649)

# %%
df['Qty'].sum()+df['Amount'].sum()
# Out:
# np.float64(78709327.29999998)

# %%
#select one col
df['Status']
# Out:
# 0                            Cancelled
# 1         Shipped - Delivered to Buyer
# 2                              Shipped
# 3                            Cancelled
# 4                              Shipped
#                       ...
# 128970                         Shipped
# 128971                         Shipped
# 128972                         Shipped
# 128973                         Shipped
# 128974                         Shipped
# Name: Status, Length: 128975, dtype: object

# %%
#multiple colms
df[['Date','Status']]
# Out:
#             Date                        Status
# 0       04-30-22                     Cancelled
# 1       04-30-22  Shipped - Delivered to Buyer
# 2       04-30-22                       Shipped
# 3       04-30-22                     Cancelled
# 4       04-30-22                       Shipped
# ...          ...                           ...
# 128970  05-31-22                       Shipped
# 128971  05-31-22                       Shipped
# 128972  05-31-22                       Shipped
# 128973  05-31-22                       Shipped
# 128974  05-31-22                       Shipped
#
# [128975 rows x 2 columns]

# %% [markdown]
# Selecting rows from a DataFrame
#
# iloc - searches using index positions
#
# loc - searches using index labels

# %%
df.iloc[4]
# Out:
# index                                   4
# Order ID              407-1069790-7240320
# Date                             04-30-22
# Status                            Shipped
# Fulfilment                         Amazon
# Sales Channel                   Amazon.in
# ship-service-level              Expedited
# Style                             JNE3671
# stock keeping unit        JNE3671-TU-XXXL
# Category                              Top
# Size                                  3XL
# ASIN                           B098714BZP
# Courier Status                    Shipped
# Qty                                     1
# currency                              INR
# Amount                              574.0
# ship-city                         CHENNAI
# ship-state                     TAMIL NADU
# ship-postal-code                 600073.0
# ship-country                           IN
# promotion-ids                         NaN
# B2B                                 False
# ...

# %%
df.iloc[0:3]
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style stock keeping unit  \
# 0   Merchant      Amazon.in           Standard   SET389     SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781    JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371      JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
# ...

# %%
#fancy indexing
df.iloc[[0,4,8]]
# Out:
#    index             Order ID      Date     Status Fulfilment Sales Channel   \
# 0      0  405-8078784-5731545  04-30-22  Cancelled   Merchant      Amazon.in
# 4      4  407-1069790-7240320  04-30-22    Shipped     Amazon      Amazon.in
# 8      8  407-5443024-5233168  04-30-22  Cancelled     Amazon      Amazon.in
#
#   ship-service-level    Style   stock keeping unit Category  ... currency  \
# 0           Standard   SET389       SET389-KR-NP-S      Set  ...      INR
# 4          Expedited  JNE3671      JNE3671-TU-XXXL      Top  ...      INR
# 8          Expedited   SET200  SET200-KR-NP-A-XXXL      Set  ...      NaN
#
#    Amount  ship-city   ship-state ship-postal-code  ship-country  \
# 0  647.62     MUMBAI  MAHARASHTRA         400081.0            IN
# 4  574.00    CHENNAI   TAMIL NADU         600073.0            IN
# 8     NaN  HYDERABAD    TELANGANA         500008.0            IN
#
#                                   promotion-ids    B2B  fulfilled-by  \
# ...

# %%
df.loc[0]
# Out:
# index                                   0
# Order ID              405-8078784-5731545
# Date                             04-30-22
# Status                          Cancelled
# Fulfilment                       Merchant
# Sales Channel                   Amazon.in
# ship-service-level               Standard
# Style                              SET389
# stock keeping unit         SET389-KR-NP-S
# Category                              Set
# Size                                    S
# ASIN                           B09KXVBD7Z
# Courier Status                        NaN
# Qty                                     0
# currency                              INR
# Amount                             647.62
# ship-city                          MUMBAI
# ship-state                    MAHARASHTRA
# ship-postal-code                 400081.0
# ship-country                           IN
# promotion-ids                         NaN
# B2B                                 False
# ...

# %%
df.loc[[0 ,2,6]]
# Out:
#    index             Order ID      Date     Status Fulfilment Sales Channel   \
# 0      0  405-8078784-5731545  04-30-22  Cancelled   Merchant      Amazon.in
# 2      2  404-0687676-7273146  04-30-22    Shipped     Amazon      Amazon.in
# 6      6  408-5748499-6859555  04-30-22    Shipped     Amazon      Amazon.in
#
#   ship-service-level    Style stock keeping unit Category  ... currency  \
# 0           Standard   SET389     SET389-KR-NP-S      Set  ...      INR
# 2          Expedited  JNE3371      JNE3371-KR-XL    kurta  ...      INR
# 6          Expedited    J0095        J0095-SET-L      Set  ...      INR
#
#    Amount    ship-city   ship-state ship-postal-code  ship-country  \
# 0  647.62       MUMBAI  MAHARASHTRA         400081.0            IN
# 2  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0            IN
# 6  653.00   CHANDIGARH   CHANDIGARH         160036.0            IN
#
#                                   promotion-ids    B2B  fulfilled-by  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   stock keeping unit  128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df['Qty']=df['Qty'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   stock keeping unit  128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int32
#  14  currency            121180 non-null  object
# ...

# %%
# More Important Functions
# value_counts
# sort_values
# sort index
# set index
# reset index
# unique & nunique
# isnull/notnull/hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %%
df.value_counts().sum()
# Out:
# np.int64(19379)

# %%
df.sort_values('Qty',ascending=True).head()
# Out:
#        index             Order ID      Date     Status Fulfilment  \
# 12820  12820  402-0048492-3712370  04-22-22  Cancelled   Merchant
# 12834  12834  404-8127662-7725119  04-22-22  Cancelled     Amazon
# 12863  12863  403-7802281-1110703  04-22-22  Cancelled     Amazon
# 12860  12860  406-3531760-8524359  04-22-22  Cancelled   Merchant
# 12850  12850  405-7984244-9061136  04-22-22  Cancelled     Amazon
#
#       Sales Channel  ship-service-level    Style stock keeping unit Category  \
# 12820      Amazon.in           Standard    J0003        J0003-SET-L      Set
# 12834      Amazon.in          Expedited    J0014        J0014-LCD-M      Set
# 12863      Amazon.in          Expedited   SET098     SET098-KR-PP-M      Set
# 12860      Amazon.in           Standard  JNE3795       JNE3795-KR-S    kurta
# 12850      Amazon.in          Expedited  MEN5009      MEN5009-KR-XL    kurta
#
#        ... currency  Amount  ship-city      ship-state ship-postal-code  \
# ...

# %%
df.sort_values(['Qty','Amount'],ascending=[True,True]).head()
# Out:
#        index             Order ID      Date     Status Fulfilment  \
# 90195  90195  405-3967780-0953102  05-01-22  Cancelled   Merchant
# 44075  44075  406-8810667-6507512  04-04-22  Cancelled   Merchant
# 45143  45143  405-2568033-6361167  04-03-22  Cancelled   Merchant
# 22770  22770  408-1332729-2342752  04-17-22  Cancelled   Merchant
# 27665  27665  404-8088699-8964305  04-14-22  Cancelled   Merchant
#
#       Sales Channel  ship-service-level    Style stock keeping unit Category  \
# 90195      Amazon.in           Standard    AN208  AN208-MUSTARD-XXL   Bottom
# 44075      Amazon.in           Standard  JNE3407     JNE3407-KR-XXL    kurta
# 45143      Amazon.in           Standard  JNE3407     JNE3407-KR-XXL    kurta
# 22770      Amazon.in           Standard  JNE3407       JNE3407-KR-L    kurta
# 27665      Amazon.in           Standard  JNE3428       JNE3428-KR-M    kurta
#
#        ... currency  Amount   ship-city     ship-state ship-postal-code  \
# ...

# %%
# sort_index(series and dataframe)
df.sort_index(ascending=True)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
# set_index(dataframe) -> inplace
df.set_index('ship-city',inplace=True)

# %%
df.head()
# Out:
#              index             Order ID      Date  \
# ship-city
# MUMBAI           0  405-8078784-5731545  04-30-22
# BENGALURU        1  171-9198151-1101146  04-30-22
# NAVI MUMBAI      2  404-0687676-7273146  04-30-22
# PUDUCHERRY       3  403-9615377-8133951  04-30-22
# CHENNAI          4  407-1069790-7240320  04-30-22
#
#                                    Status Fulfilment Sales Channel   \
# ship-city
# MUMBAI                          Cancelled   Merchant      Amazon.in
# BENGALURU    Shipped - Delivered to Buyer   Merchant      Amazon.in
# NAVI MUMBAI                       Shipped     Amazon      Amazon.in
# PUDUCHERRY                      Cancelled   Merchant      Amazon.in
# CHENNAI                           Shipped     Amazon      Amazon.in
#
#             ship-service-level    Style stock keeping unit       Category  \
# ship-city
# MUMBAI                Standard   SET389     SET389-KR-NP-S            Set
# ...

# %%
# reset_index(series + dataframe) -> drop parameter
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#      ship-city  index             Order ID      Date  \
# 0       MUMBAI      0  405-8078784-5731545  04-30-22
# 1    BENGALURU      1  171-9198151-1101146  04-30-22
# 2  NAVI MUMBAI      2  404-0687676-7273146  04-30-22
# 3   PUDUCHERRY      3  403-9615377-8133951  04-30-22
# 4      CHENNAI      4  407-1069790-7240320  04-30-22
#
#                          Status Fulfilment Sales Channel  ship-service-level  \
# 0                     Cancelled   Merchant      Amazon.in           Standard
# 1  Shipped - Delivered to Buyer   Merchant      Amazon.in           Standard
# 2                       Shipped     Amazon      Amazon.in          Expedited
# 3                     Cancelled   Merchant      Amazon.in           Standard
# 4                       Shipped     Amazon      Amazon.in          Expedited
#
#      Style stock keeping unit  ... Qty currency  Amount   ship-state  \
# 0   SET389     SET389-KR-NP-S  ...   0      INR  647.62  MAHARASHTRA
# ...

# %%
# how to replace existing index without loosing
df.reset_index().set_index('ship-state').head()
# Out:
#              level_0    ship-city  index             Order ID      Date  \
# ship-state
# MAHARASHTRA        0       MUMBAI      0  405-8078784-5731545  04-30-22
# KARNATAKA          1    BENGALURU      1  171-9198151-1101146  04-30-22
# MAHARASHTRA        2  NAVI MUMBAI      2  404-0687676-7273146  04-30-22
# PUDUCHERRY         3   PUDUCHERRY      3  403-9615377-8133951  04-30-22
# TAMIL NADU         4      CHENNAI      4  407-1069790-7240320  04-30-22
#
#                                    Status Fulfilment Sales Channel   \
# ship-state
# MAHARASHTRA                     Cancelled   Merchant      Amazon.in
# KARNATAKA    Shipped - Delivered to Buyer   Merchant      Amazon.in
# MAHARASHTRA                       Shipped     Amazon      Amazon.in
# PUDUCHERRY                      Cancelled   Merchant      Amazon.in
# TAMIL NADU                        Shipped     Amazon      Amazon.in
#
#             ship-service-level    Style  ... Courier Status Qty currency  \
# ...

# %%
# nunique(series + dataframe) -> does not count nan -> dropna parameter
df['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
# isnull(series + dataframe)
df.isnull().sum()
# Out:
# ship-city                33
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# stock keeping unit        0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.notnull().sum() # notnull(series + dataframe)
# Out:
# ship-city             128942
# index                 128975
# Order ID              128975
# Date                  128975
# Status                128975
# Fulfilment            128975
# Sales Channel         128975
# ship-service-level    128975
# Style                 128975
# stock keeping unit    128975
# Category              128975
# Size                  128975
# ASIN                  128975
# Courier Status        122103
# Qty                   128975
# currency              121180
# Amount                121180
# ship-state            128942
# ship-postal-code      128942
# ship-country          128942
# promotion-ids          79822
# B2B                   128975
# fulfilled-by           39277
# Unnamed: 22            79925
# dtype: int64

# %%
df['Amount'].hasnans
# Out:
# True

# %%
df['Amount'].dropna()
# Out:
# 0          647.62
# 1          406.00
# 2          329.00
# 3          753.33
# 4          574.00
#            ...
# 128970     517.00
# 128971     999.00
# 128972     690.00
# 128973    1199.00
# 128974     696.00
# Name: Amount, Length: 121180, dtype: float64

# %%
df.dropna(how='all')
# Out:
#           ship-city   index             Order ID      Date  \
# 0            MUMBAI       0  405-8078784-5731545  04-30-22
# 1         BENGALURU       1  171-9198151-1101146  04-30-22
# 2       NAVI MUMBAI       2  404-0687676-7273146  04-30-22
# 3        PUDUCHERRY       3  403-9615377-8133951  04-30-22
# 4           CHENNAI       4  407-1069790-7240320  04-30-22
# ...             ...     ...                  ...       ...
# 128970    HYDERABAD  128970  406-6001380-7673107  05-31-22
# 128971     GURUGRAM  128971  402-9551604-7544318  05-31-22
# 128972    HYDERABAD  128972  407-9547469-3152358  05-31-22
# 128973        Halol  128973  402-6184140-0545956  05-31-22
# 128974       Raipur  128974  408-7436540-8728312  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# ...

# %%
df.dropna(subset=['fulfilled-by'])
# Out:
#              ship-city   index             Order ID      Date  \
# 0               MUMBAI       0  405-8078784-5731545  04-30-22
# 1            BENGALURU       1  171-9198151-1101146  04-30-22
# 3           PUDUCHERRY       3  403-9615377-8133951  04-30-22
# 7            HYDERABAD       7  406-7807733-3785945  04-30-22
# 12           Amravati.      12  405-5513694-8146768  04-30-22
# ...                ...     ...                  ...       ...
# 128874           ALLUR  128874  405-4724097-1016369  06-01-22
# 128875       Barabanki  128875  403-9524128-9243508  06-01-22
# 128887           NOIDA  128887  405-6493630-8542756  05-31-22
# 128890         MADURAI  128890  407-0116398-1810752  05-31-22
# 128891  UTTAR BAGDOGRA  128891  403-0317423-9322704  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# ...

# %%
df.dropna(subset=['ship-state','ship-city'])
# Out:
#           ship-city   index             Order ID      Date  \
# 0            MUMBAI       0  405-8078784-5731545  04-30-22
# 1         BENGALURU       1  171-9198151-1101146  04-30-22
# 2       NAVI MUMBAI       2  404-0687676-7273146  04-30-22
# 3        PUDUCHERRY       3  403-9615377-8133951  04-30-22
# 4           CHENNAI       4  407-1069790-7240320  04-30-22
# ...             ...     ...                  ...       ...
# 128970    HYDERABAD  128970  406-6001380-7673107  05-31-22
# 128971     GURUGRAM  128971  402-9551604-7544318  05-31-22
# 128972    HYDERABAD  128972  407-9547469-3152358  05-31-22
# 128973        Halol  128973  402-6184140-0545956  05-31-22
# 128974       Raipur  128974  408-7436540-8728312  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# ...

# %%
# fillna(series + dataframe)
df['Status'].fillna('unknown')
# Out:
# 0                            Cancelled
# 1         Shipped - Delivered to Buyer
# 2                              Shipped
# 3                            Cancelled
# 4                              Shipped
#                       ...
# 128970                         Shipped
# 128971                         Shipped
# 128972                         Shipped
# 128973                         Shipped
# 128974                         Shipped
# Name: Status, Length: 128975, dtype: object

# %%
# drop_duplicates(series + dataframe) -> works like and -> duplicated()
df.drop_duplicates()
# Out:
#           ship-city   index             Order ID      Date  \
# 0            MUMBAI       0  405-8078784-5731545  04-30-22
# 1         BENGALURU       1  171-9198151-1101146  04-30-22
# 2       NAVI MUMBAI       2  404-0687676-7273146  04-30-22
# 3        PUDUCHERRY       3  403-9615377-8133951  04-30-22
# 4           CHENNAI       4  407-1069790-7240320  04-30-22
# ...             ...     ...                  ...       ...
# 128970    HYDERABAD  128970  406-6001380-7673107  05-31-22
# 128971     GURUGRAM  128971  402-9551604-7544318  05-31-22
# 128972    HYDERABAD  128972  407-9547469-3152358  05-31-22
# 128973        Halol  128973  402-6184140-0545956  05-31-22
# 128974       Raipur  128974  408-7436540-8728312  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# ...

# %%
# drop(series + dataframe)
#their purpose: drop() removes specified labels (rows or columns)
#while drop_duplicates() specifically targets and removes duplicate rows.

# %%
df.drop(index=[0,4])
# Out:
#           ship-city   index             Order ID      Date  \
# 1         BENGALURU       1  171-9198151-1101146  04-30-22
# 2       NAVI MUMBAI       2  404-0687676-7273146  04-30-22
# 3        PUDUCHERRY       3  403-9615377-8133951  04-30-22
# 5         GHAZIABAD       5  404-1490984-4578765  04-30-22
# 6        CHANDIGARH       6  408-5748499-6859555  04-30-22
# ...             ...     ...                  ...       ...
# 128970    HYDERABAD  128970  406-6001380-7673107  05-31-22
# 128971     GURUGRAM  128971  402-9551604-7544318  05-31-22
# 128972    HYDERABAD  128972  407-9547469-3152358  05-31-22
# 128973        Halol  128973  402-6184140-0545956  05-31-22
# 128974       Raipur  128974  408-7436540-8728312  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# 3                          Cancelled   Merchant      Amazon.in
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.drop('Unnamed: 22',axis=1)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
#df.drop(columns=['col1', 'col3'])
